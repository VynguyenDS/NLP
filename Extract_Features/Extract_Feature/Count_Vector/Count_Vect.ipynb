# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer

# %%
text = ["I love NLP and I will learn NLP in 2month", "NLP is future"]
data = pd.DataFrame(text)
data.columns = ['text']
data['text'] = data['text'].str.lower()
data['text'].values
# Out:
# array(['i love nlp and i will learn nlp in 2month', 'nlp is future'],
#       dtype=object)

# %%
countvectorizer = CountVectorizer()

# %%
vectorizer.fit(data['text'].values)
# Out:
# CountVectorizer()

# %%
count_wm = countvectorizer.fit_transform(data['text'].values)

# %%
count_tokens = countvectorizer.get_feature_names()
df_countvect = pd.DataFrame(data = count_wm.toarray(),index = ['Doc1','Doc2'],columns = count_tokens)
df_countvect
# Out:
#       2month  and  future  in  is  learn  love  nlp  will
# Doc1       1    1       0   1   0      1     1    2     1
# Doc2       0    0       1   0   1      0     0    1     0

# %%
print(vector.toarray())
# pd.DataFrame(columns = vectorizer.vocabulary_.keys(), data = vector.toarray())
# Out:
# [[1 1 0 1 0 1 1 2 1]
#  [0 0 1 0 1 0 0 1 0]]

# %%
text = ["I love NLP and I will learn NLP in 2month", "NLP is future"]
unique_words = set()

# %%
unique_words = [j for i in text for j in i.split() if len(j) > 2]
unique_words
# Out:
# ['love', 'NLP', 'and', 'will', 'learn', 'NLP', '2month', 'NLP', 'future']

# %%
unique_words = dict.fromkeys(unique_words,0)
unique_words
# Out:
# {'love': 0,
#  'NLP': 0,
#  'and': 0,
#  'will': 0,
#  'learn': 0,
#  '2month': 0,
#  'future': 0}
